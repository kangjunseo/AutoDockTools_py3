# %% [markdown]
# ### INCI_list

# %%
INCI_list = ['Benzethonium Chloride', 'Leuconostoc/Salix Alba (Willow) Bark Extract Ferment Filtrate', 'Urtica Dioica (Nettle) Extract', 'Hexapeptide-11', 'Prunus Armeniaca (Apricot) Fruit Extract', 'Betula Alba Leaf Extract', 'Arginine HCl', 'Isosorbide', 'Bis-Ethylhexyloxyphenol Methoxyphenyl Triazine', 'Sodium Lauroyl Glutamate', 'Psicose', 'Hydroxyethylcellulose', 'Passiflora Edulis Fruit Juice', 'Scutellaria Alpina Flower/Leaf/Stem Extract', 'Shea Butteramidopropyl Betaine', 'Ozokerite', 'Hydrogenated Coco-Glycerides', 'Centella Asiatica Extract', 'Annona Cherimola Fruit Extract', 'Sodium Carrageenan', 'Cetyl Ethylhexanoate', 'Calcium Alginate', 'Cellulose Acetate Propionate', 'Pyridoxine Dipalmitate', 'Sodium Hydroxymethylglycinate', 'Methylcellulose', 'Oxothiazolidinecarboxylic Acid', 'Octyldodecanol', 'PPG-30', 'CI 16255', 'Polyglyceryl-4 Pelargonate', 'Ethylparaben', 'Colloidal Oatmeal', 'Pseudoalteromonas Ferment Extract', 'Glucosamine HCl', 'Petroleum Distillates', '1,2-Hexanediol', 'Virola Sebifera Nut Oil', 'Cinchona Calisaya Extract', 'Hydrolyzed Corn Starch', 'Isostearyl Isostearate', 'Mentha Piperita (Peppermint) Leaf Extract', 'Lauramide MIPA', 'Glyceryl Oleate', 'Palmitoyl Hydroxypropyltrimonium Amylopectin/Glycerin Crosspolymer', 'Saccharomyces/Calcium Ferment', 'Cocos Nucifera (Coconut) Oil', 'Pentapeptide-28', 'Trimethoxycaprylylsilane', 'Sodium Bicarbonate', 'Caramel', 'Polyquaternium-88', 'Vegetable Oil', 'Polyglyceryl-2 Isostearate', 'Silicone Quaternium-22', 'Potassium Cocoyl Hydrolyzed Soy Protein', 'Iodopropynyl Butylcarbamate', 'Sodium Cocoyl Glutamate', 'Trideceth-3', 'Tridecyl Neopentanoate', 'Iron Oxides (CI 77491)', 'Sodium Carboxymethyl Starch', 'Eucalyptus Globulus Leaf Oil', 'Malva Sylvestris (Mallow) Flower/Leaf Extract', 'Sulfur', 'CI 42090', 'PPG-5-Ceteth-20', 'Tropaeolum Majus Flower Extract', 'Capsaicin', 'Octadecene', 'Citronellol', 'Ceteareth-25', 'Hydroxypropyltrimonium Hydrolyzed Wheat Protein', 'Centaurea Cyanus Flower Extract', 'Aesculus Chinensis Extract', 'Diethylhexyl Sodium Sulfosuccinate', 'Gluconic Acid', 'Hydrofluorocarbon 227ea', 'Portulaca Oleracea Extract', 'PEG-30 Dipolyhydroxystearate', 'Cyclomethicone', 'Cymbopogon Flexuosus Oil', 'Silybum Marianum Extract', 's-DNA Aptamer-4', 'Methicone', 'Citrate Buffer', 'Laurocapram', 'Fragaria Vesca (Strawberry) Fruit Extract', 'C11-15 Alketh-7 (Formerly C11-15 Pareth-7)', 'Acetic Acid', 'Acid Blue 9 Aluminum Lake', 'Bis-Glyoxyloyl Cystine', 'Butyl Acetate', 
ract', 'Quaternium-80', 'Cinchona Succirubra Bark Extract', 'Bis-PEG-15 Dimethicone/IPDI Copolymer', 'Ananas Sativus (Pineapple) Fruit Juice', 'Potassium Abietoyl Hydrolyzed Soy Protein', 'Citrus Nobilis (Mandarin Orange) Peel Extract', 'Threonine', 'Tocopheryl Acetate', 'PVP', 'Aloe Barbadensis Leaf Juice', 'Crithmum Maritimum Callus Culture Filtrate', 'Coleus Barbatus Root Extract', 'Alpha-Glucan Oligosaccharide', 'Agar', 'Quaternium-95', 'Triclosan', 'Sodium Acrylate/Sodium Acryloyldimethyl Taurate Copolymer', 'Lactobacillus/Rye Flour Ferment Filtrate', 'Citrulline', 'Tin Oxide', 'Calophyllum Inophyllum Seed Oil', 'Rehmannia Chinensis Root Extract', 'Nannochloropsis Oculata Extract', 'Rhus Succedanea Fruit Wax', 'Sodium Stearate', 'Palmitoyl Tripeptide-5', 'Bisabolol', 'Panthenol', 'Oryza Sativa (Rice) Germ Extract', 'Oryza Sativa (Rice) Starch', 'Malpighia Glabra (Acerola) Fruit Extract', 'Chrysin', 'Potassium Laureth-4 Carboxylate', 'Red 36', 'Urtica Dioica (Nettle) Leaf Extract', 'Trideceth-12', 'PPG-14 Butyl Ether', 'Lithospermum Erythrorhizon Root Extract', 'Aminoethylphosphinic Acid', 'Starch Acetate', 'Persea Gratissima (Avocado) Butter', 'Sucrose Stearate', 'Ammonium Lauryl Sulfate', 'CI 77288', 'Polyurethane-2', 'Magnolia Liliflora Flower Extract', 'Cichorium Intybus (Chicory) Seed Oil', 'Lactobacillus Ferment', 'Limnanthes Alba (Meadowfoam) Seed Oil', 'Caryocar Brasiliense Fruit Oil', 'Ornithine', 'Punica Granatum Pericarp Extract', 'Glycyrrhetinic Acid', 'Hydrolyzed Barley Protein', 'Sodium Cocoyl Hydrolyzed Wheat Protein', 'Melaleuca Alternifolia (Tea Tree) Leaf Oil', 'Isoleucine', 'Sodium Gluconate', 'Phenylpropanol', 'Trisiloxane', 'Glyoxyloyl Cysteine', 'Curcumin', 'Primula Veris Extract', 'Mel', 'CI 61585', 'Sodium Cocoamphohydroxypropylsulfonate', 'Red 21', 'Coleus Forskohlii Root Extract', 'Ammonium Carbonate', 'Gossypium Herbaceum (Cotton) Seed Oil', 'Caprylic Acid', 'Diglucosyl Gallic Acid', 'Behenyl Alcohol', 'Citrullus Lanatus (Watermelon) Fruit Extract', 'Urtica Dioica (Nettle) Leaf Powder']
print(len(INCI_list))
# Out:
# 2039

# %%
import csv

with open('INCI_List.csv', 'w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(INCI_list)

# %% [markdown]
# ### INCI_SMILES

# %%
import os
import subprocess

# %%
import pandas as pd

INCI_SMILES_df = pd.read_csv('INCI_List.csv', header=None)
INCI_SMILES_df = INCI_SMILES_df.T
INCI_SMILES_df.columns = ['INCI']
INCI_SMILES_df
# Out:
#                                                    INCI
# 0                                 Benzethonium Chloride
# 1     Leuconostoc/Salix Alba (Willow) Bark Extract F...
# 2                        Urtica Dioica (Nettle) Extract
# 3                                        Hexapeptide-11
# 4              Prunus Armeniaca (Apricot) Fruit Extract
# ...                                                 ...
# 2034                                      Caprylic Acid
# 2035                             Diglucosyl Gallic Acid
# 2036                                    Behenyl Alcohol
# 2037       Citrullus Lanatus (Watermelon) Fruit Extract
# 2038                 Urtica Dioica (Nettle) Leaf Powder
#
# [2039 rows x 1 columns]

# %%
import requests
import time
from urllib.parse import quote

# 사용자 에이전트 헤더 추가
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}

# PubChem 요청 시 서버 바쁨 오류 처리 및 재시도 로직 추가
def get_smiles(INCI, retries=5, delay=5):

       # Helper function to make requests with headers
    def make_request(identifier, namespace):
        url = f"https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/{namespace}/{quote(identifier)}/property/CanonicalSMILES/TXT"
        response = requests.get(url, headers=headers, timeout=10)
        response.raise_for_status()  # Raise an exception for HTTP errors
        return response.text.strip()


    # INCI Name으로 검색


    for attempt in range(retries):
        try:
            smiles = make_request(INCI, 'name')
            if smiles: return smiles
        except requests.HTTPError as e:
            if e.response.status_code == 404:
                print(f"Not found: {INCI} (404 error)")
                break
            elif e.response.status_code == 400:
                print(f"Bad request: {INCI} (400 error)")
                break
            elif 'PUGREST.ServerBusy' in str(e):
                print(f"Server busy: {e}. Retrying ({attempt + 1}/{retries}) in {delay} seconds...")
                time.sleep(delay)
            else:
                raise e
        except (requests.ConnectionError, requests.Timeout) as e:
            print(f"Connection error: {e}. Retrying ({attempt + 1}/{retries}) in {delay} seconds...")
            time.sleep(delay)
    return None

#cos_table['SMILES'] = cos_table.apply(lambda row: get_smiles(row["Name"], row['INCI Name']), axis=1)
INCI_SMILES_df['SMILES'] = INCI_SMILES_df.apply(lambda row: get_smiles(row["INCI"]), axis=1)
INCI_SMILES_df
# Out:
# Not found: Leuconostoc/Salix Alba (Willow) Bark Extract Ferment Filtrate (404 error)
# Not found: Urtica Dioica (Nettle) Extract (404 error)
# Not found: Prunus Armeniaca (Apricot) Fruit Extract (404 error)
# Not found: Betula Alba Leaf Extract (404 error)
# Not found: Passiflora Edulis Fruit Juice (404 error)
# Not found: Scutellaria Alpina Flower/Leaf/Stem Extract (404 error)
# Not found: Shea Butteramidopropyl Betaine (404 error)
# Not found: Hydrogenated Coco-Glycerides (404 error)
# Not found: Centella Asiatica Extract (404 error)
# Not found: Annona Cherimola Fruit Extract (404 error)
# Not found: Sodium Carrageenan (404 error)
# Not found: PPG-30 (404 error)
# Not found: Polyglyceryl-4 Pelargonate (404 error)
# Not found: Colloidal Oatmeal (404 error)
# Not found: Pseudoalteromonas Ferment Extract (404 error)
# Not found: Petroleum Distillates (404 error)
# Not found: Virola Sebifera Nut Oil (404 error)
# Not found: Cinchona Calisaya Extract (404 error)
# ...

# %%
#INCI_SMILES_df.to_csv("INCI_SMILES.csv")
INCI_SMILES_df = pd.read_csv("INCI_SMILES.csv")
INCI_SMILES_df = INCI_SMILES_df.dropna(subset=["SMILES"])
INCI_SMILES_df
# Out:
#       Unnamed: 0                                            INCI  \
# 0              0                           Benzethonium Chloride
# 3              3                                  Hexapeptide-11
# 6              6                                    Arginine HCl
# 7              7                                      Isosorbide
# 8              8  Bis-Ethylhexyloxyphenol Methoxyphenyl Triazine
# ...          ...                                             ...
# 2028        2028                                        CI 61585
# 2030        2030                                          Red 21
# 2032        2032                              Ammonium Carbonate
# 2034        2034                                   Caprylic Acid
# 2036        2036                                 Behenyl Alcohol
#
#                                                  SMILES
# 0     CC(C)(C)CC(C)(C)C1=CC=C(C=C1)OCCOCC[N+](C)(C)C...
# 3     CC(C)C(C(=O)NC(C)C(=O)N1CCCC1C(=O)NC(CC2=CC=CC...
# ...

# %%
from rdkit import Chem
from rdkit.Chem import SaltRemover

def salt_remove(smiles):
    remover = SaltRemover.SaltRemover()
    
    # Mol 객체 생성
    mol = Chem.MolFromSmiles(smiles)
    # 염 제거
    clean_mol = remover.StripMol(mol, dontRemoveEverything=True)
    # SMILES로 변환
    clean_smiles = Chem.MolToSmiles(clean_mol)
    
    return clean_smiles

INCI_SMILES_df["Clean SMILES"] = INCI_SMILES_df['SMILES'].apply(salt_remove)
INCI_SMILES_df
# Out:
# [15:45:39] WARNING: not removing hydrogen atom without neighbors
# [15:45:39] WARNING: not removing hydrogen atom without neighbors
#       Unnamed: 0                                            INCI  \
# 0              0                           Benzethonium Chloride
# 3              3                                  Hexapeptide-11
# 6              6                                    Arginine HCl
# 7              7                                      Isosorbide
# 8              8  Bis-Ethylhexyloxyphenol Methoxyphenyl Triazine
# ...          ...                                             ...
# 2028        2028                                        CI 61585
# 2030        2030                                          Red 21
# 2032        2032                              Ammonium Carbonate
# 2034        2034                                   Caprylic Acid
# 2036        2036                                 Behenyl Alcohol
#
# ...

# %%
from rdkit import Chem

def is_organic(smiles):
    metals = ['Li', 'Be', 'Na', 'Mg', 'Al', 'K', 'Ca', 'Sc', 'Ti', 'V', 'Cr', 'Mn', 'Fe', 'Co', 'Ni', 'Cu', 'Zn', 'Ga', 'Rb', 'Sr', 'Y', 'Zr', 'Nb', 'Mo', 'Tc', 'Ru', 'Rh', 'Pd', 'Ag', 'Cd', 'In', 'Sn', 'Sb', 'Cs', 'Ba', 'La', 'Ce', 'Pr', 'Nd', 'Pm', 'Sm', 'Eu', 'Gd', 'Tb', 'Dy', 'Ho', 'Er', 'Tm', 'Yb', 'Lu', 'Hf', 'Ta', 'W', 'Re', 'Os', 'Ir', 'Pt', 'Au', 'Hg', 'Tl', 'Pb', 'Bi', 'Po', 'Fr', 'Ra', 'Ac', 'Th', 'Pa', 'U', 'Np', 'Pu', 'Am', 'Cm', 'Bk', 'Cf', 'Es', 'Fm', 'Md', 'No', 'Lr']
    try:
        mol = Chem.MolFromSmiles(smiles)
        if mol is not None:
            has_carbon = any(atom.GetSymbol() == 'C' for atom in mol.GetAtoms())
            is_inorganic = any(atom.GetSymbol() in metals for atom in mol.GetAtoms())
            return has_carbon and not is_inorganic
    except:
        return False
    return False

organic_SMILES = INCI_SMILES_df[INCI_SMILES_df['Clean SMILES'].apply(is_organic)]
organic_SMILES
# Out:
# [15:46:21] WARNING: not removing hydrogen atom without neighbors
# [15:46:21] WARNING: not removing hydrogen atom without neighbors
#       Unnamed: 0                                            INCI  \
# 0              0                           Benzethonium Chloride
# 3              3                                  Hexapeptide-11
# 6              6                                    Arginine HCl
# 7              7                                      Isosorbide
# 8              8  Bis-Ethylhexyloxyphenol Methoxyphenyl Triazine
# ...          ...                                             ...
# 2028        2028                                        CI 61585
# 2030        2030                                          Red 21
# 2032        2032                              Ammonium Carbonate
# 2034        2034                                   Caprylic Acid
# 2036        2036                                 Behenyl Alcohol
#
# ...

# %%
import os
import subprocess

def sanitize_filename(filename): return filename.replace(' ', '_')

output_dir = 'smiles_pdb2'
os.makedirs(output_dir, exist_ok=True)

suc = 0
fail = 0
failed = []

for idx, row in organic_SMILES.iterrows():
    name = row["INCI"]
    smiles = row['SMILES']
    output_file = os.path.join(output_dir, f"{name}.pdb")
    output_file = sanitize_filename(output_file)

    command = f'obabel -:"{smiles}" -O {output_file} --gen3d'

    try:
        subprocess.run(command, shell=True, check=True, stderr=subprocess.PIPE, stdout=subprocess.PIPE)
        print(f"Converted {name} to {output_file}")
        suc +=1
    except subprocess.CalledProcessError as e:
        print(f"Error converting {name}: {e}")
        fail +=1
        failed.append(name)

print("Conversion completed.")
print(f'{suc} successed, {fail} failed')
print(failed)
# Out:
# Converted Benzethonium Chloride to smiles_pdb2/Benzethonium_Chloride.pdb
# Converted Hexapeptide-11 to smiles_pdb2/Hexapeptide-11.pdb
# Converted Arginine HCl to smiles_pdb2/Arginine_HCl.pdb
# Converted Isosorbide to smiles_pdb2/Isosorbide.pdb
# Converted Bis-Ethylhexyloxyphenol Methoxyphenyl Triazine to smiles_pdb2/Bis-Ethylhexyloxyphenol_Methoxyphenyl_Triazine.pdb
# Converted Sodium Lauroyl Glutamate to smiles_pdb2/Sodium_Lauroyl_Glutamate.pdb
# Converted Psicose to smiles_pdb2/Psicose.pdb
# Converted Hydroxyethylcellulose to smiles_pdb2/Hydroxyethylcellulose.pdb
# Converted Ozokerite to smiles_pdb2/Ozokerite.pdb
# Converted Cetyl Ethylhexanoate to smiles_pdb2/Cetyl_Ethylhexanoate.pdb
# Converted Calcium Alginate to smiles_pdb2/Calcium_Alginate.pdb
# Converted Cellulose Acetate Propionate to smiles_pdb2/Cellulose_Acetate_Propionate.pdb
# Converted Pyridoxine Dipalmitate to smiles_pdb2/Pyridoxine_Dipalmitate.pdb
# ...

# %%
#['Olea Europaea (Olive) Leaf Extract', "N,N'-Bis(2-Hydroxyethyl)-2-Nitro-p-Phenylenediamine"]
INCI_SMILES_df[INCI_SMILES_df['INCI'].isin(failed)]
# Out:
#       Unnamed: 0                                               INCI  \
# 410          410                 Olea Europaea (Olive) Leaf Extract
# 1342        1342  N,N'-Bis(2-Hydroxyethyl)-2-Nitro-p-Phenylenedi...
#
#                                                  SMILES  \
# 410   CC1=NN=C(C=C1)N2C(C(=C(C3=CC=C(C=C3)C(C)C)O)C(...
# 1342                C1=CC(=C(C=C1NCCO)[N+](=O)[O-])NCCO
#
#                                            Clean SMILES
# 410   Cc1ccc(N2C(=O)C(=O)C(=C(O)c3ccc(C(C)C)cc3)C2c2...
# 1342                     O=[N+]([O-])c1cc(NCCO)ccc1NCCO

# %% [markdown]
# ### PDB to PDBQT

# %%
os.path.exists('/home/kjs/Downloads/autodocktools-prepare-py3k/pycode/smiles_pdb/Hexapeptide-9.pdb')
# Out:
# True

# %%
import os
import subprocess

#"/home/kjs/Downloads/autodocktools-prepare-py3k/AutoDockTools/Utilities24/prepare_ligand4.py"
#"/home/kjs/Downloads/mgltools_x86_64Linux2_1.5.7/MGLToolsPckgs/AutoDockTools/Utilities24/prepare_ligand4.py"
current_dir = os.getcwd()
suc, fail, failed = 0, 0, []

def prepare_ligand(pdb_file, output_file):
    global suc, fail, failed
    output_file = os.path.join(output_file, os.path.basename(pdb_file).replace('.pdb', '.pdbqt'))
    try:
        prepare_ligand_path = "/home/kjs/Downloads/autodocktools-prepare-py3k/AutoDockTools/Utilities24/prepare_ligand5.py"
        command = f'python3 {prepare_ligand_path} -l {pdb_file} -o {output_file} -A hydrogens'
        result = subprocess.run(command, shell=True, check=True, stderr=subprocess.PIPE, stdout=subprocess.PIPE)
        stdout_output = result.stdout.decode('utf-8')
        stderr_output = result.stderr.decode('utf-8')

        print(f"Processed {pdb_file} to {output_file}")
        print("Standard Output:")
        print(stdout_output)
        suc+=1

        if stderr_output:
            print("Standard Error:")
            print(stderr_output)
            suc-=1
            fail+=1
            failed.append(pdb_file)

    except subprocess.CalledProcessError as e:
        print(f"Error converting {pdb_file} to PDBQT: {e.stderr.decode('utf-8')}")
        fail+=1
        failed.append(pdb_file)

pdb_path = os.path.join(current_dir, 'smiles_pdb2')
output_path = os.path.join(pdb_path, 'pdbqt')

for root ,dirs, files in os.walk(pdb_path):
    for file in files:
        if file.endswith('.pdb'):
            pdb_file_path = os.path.join(root, file)
            #print(pdb_file_path)
            prepare_ligand(pdb_file_path, output_path)

print(suc, fail, failed)

# %%
flex_ligs = '"D:ARG557 GLU570"'
command = f'python3 {prepare_flex_path} -r {pdb_file} -s {flex_ligs} -o {output_file}'
command
# Out:
# 'python3 /home/kjs/Downloads/autodocktools-prepare-py3k/AutoDockTools/Utilities24/prepare_flexreceptor4.py -r /home/kjs/Downloads/autodocktools-prepare-py3k/pycode/apo_8gfa.pdbqt -s "D:ARG557 GLU570" -o /home/kjs/Downloads/autodocktools-prepare-py3k/pycode/apo_8gfa_flex.pdbqt'

# %%
cnt=0
pdbqt=0

pdbs=[]
pdbqts=[]

for root ,dirs, files in os.walk(pdb_path):
    for file in files:
        if file.endswith('.pdb'):
            pdbs.append(file[:-4])
            cnt+=1
        else: 
            pdbqts.append(file[:-6])
            pdbqt+=1

print(cnt, pdbqt, [x for x in pdbs if x not in pdbqts])
# Out:
# 664 639 ['Arginine_Ferulate', 'Disodium_Cocoyl_Glutamate', 'Carbon', 'Carbon_Black', 'CI_77266', 'Sodium_Polyglutamate', 'Potassium_Lauroyl_Glutamate', 'Sodium_Lauroyl_Glutamate', 'Sodium_Dilauramidoglutamide_Lysine', 'Palmitoyl_Tripeptide-5', 'Arginine_PCA', 'Sodium_Cocoyl_Glutamate', 'Disteardimonium_Hectorite', 'Cysteine', 'Black_2', 'Arginine_HCl', 'TEA-Cocoyl_Glutamate', 'Arginine_Aspartate', 'Ciclopirox_Olamine', 'Lysine_HCl', 'Palmitoyl_Tripeptide-1', 'TEA-Lauroyl_Glutamate', 'Piroctone_Olamine', 'Stearalkonium_Hectorite', 'Dihydroxypropyl_Arginine_HCl']

# %%
import os
import subprocess

suc, fail, failed = 0, 0, []

def dock_ligand(receptor, ligand, output):
    global suc, fail, failed
    vina_executable = "/home/kjs/Downloads/autodock_vina_1_1_2_linux_x86/bin/vina"  # AutoDock Vina 실행 파일 경로 설정
    try:
        command = [
            vina_executable,
            '--receptor', receptor,
            '--ligand', ligand,
            '--out', output,
            '--log', output.replace('.pdbqt', '.log'),
            '--center_x', '-23.075', '--center_y', '-2.183', '--center_z', '-7.899',  # 이 값을 조정하여 도킹 박스의 중심을 설정하십시오.
            '--size_x', '30', '--size_y', '30', '--size_z', '30'  # 이 값을 조정하여 도킹 박스의 크기를 설정하십시오.
        ]
        result = subprocess.run(command, check=True, stderr=subprocess.PIPE, stdout=subprocess.PIPE)
        print(f"Docked {ligand} to {receptor}, output saved to {output}")
        suc+=1
    except subprocess.CalledProcessError as e:
        print(f"Error docking {ligand} to {receptor}: {e.stderr.decode('utf-8')}")
        fail+=1
        failed.append(ligand)

receptor = 'apo_8gfa.pdbqt'
ligands_dir = 'smiles_pdb2/pdbqt'
output_dir = 'docked_results'

os.makedirs(output_dir, exist_ok=True)

ligands = [f for f in os.listdir(ligands_dir) if f.endswith('.pdbqt')]

for ligand in ligands:
    ligand_path = os.path.join(ligands_dir, ligand)
    output_path = os.path.join(output_dir, f'docked_{ligand}')
    
    if os.path.exists(output_path): continue

    dock_ligand(receptor, ligand_path, output_path)

print(suc, fail, failed)
# Out:
# Docked smiles_pdb2/pdbqt/Sodium_Ascorbate.pdbqt to apo_8gfa.pdbqt, output saved to docked_results/docked_Sodium_Ascorbate.pdbqt
# Docked smiles_pdb2/pdbqt/Tridecyl_Stearate.pdbqt to apo_8gfa.pdbqt, output saved to docked_results/docked_Tridecyl_Stearate.pdbqt
# Docked smiles_pdb2/pdbqt/Lactose.pdbqt to apo_8gfa.pdbqt, output saved to docked_results/docked_Lactose.pdbqt
# Docked smiles_pdb2/pdbqt/Adenosine.pdbqt to apo_8gfa.pdbqt, output saved to docked_results/docked_Adenosine.pdbqt
# Docked smiles_pdb2/pdbqt/Alcohol.pdbqt to apo_8gfa.pdbqt, output saved to docked_results/docked_Alcohol.pdbqt
# Docked smiles_pdb2/pdbqt/Octyldodecyl_Myristate.pdbqt to apo_8gfa.pdbqt, output saved to docked_results/docked_Octyldodecyl_Myristate.pdbqt
# Docked smiles_pdb2/pdbqt/Cellulose_Acetate_Propionate.pdbqt to apo_8gfa.pdbqt, output saved to docked_results/docked_Cellulose_Acetate_Propionate.pdbqt
# ...

# %%
#Make flexible receptor
current_dir = os.getcwd()
prepare_flex_path = "/home/kjs/Downloads/AutoDockTools_py3/AutoDockTools/Utilities24/prepare_flexreceptor4.py"
pdb_file = os.path.join(current_dir, 'apo_8gfa.pdbqt')
output_file = os.path.join(current_dir, 'apo_8gfa_flex.pdbqt')
output_file_r = os.path.join(current_dir, 'apo_8gfa_rigid.pdbqt')
flex_ligs = 'apo_8gfa:D:ARG557_GLU570'

command = f'python3 {prepare_flex_path} -r {pdb_file} -s {flex_ligs} -x {output_file} -g {output_file_r}'
result = subprocess.run(command, shell=True, check=True, stderr=subprocess.PIPE, stdout=subprocess.PIPE)
stdout_output = result.stdout.decode('utf-8')
stderr_output = result.stderr.decode('utf-8')

print(f"Processed {pdb_file} to {output_file}")
print("Standard Output:")
print(stdout_output)
# Out:
# Processed /home/kjs/Downloads/AutoDockTools_py3/pycode/apo_8gfa.pdbqt to /home/kjs/Downloads/AutoDockTools_py3/pycode/apo_8gfa_flex.pdbqt
# Standard Output:

# %%
import os
import subprocess

suc, fail, failed = 0, 0, []

def dock_ligand(r_receptor, f_receptor, ligand, output):
    global suc, fail, failed
    vina_executable = "/home/kjs/Downloads/autodock_vina_1_1_2_linux_x86/bin/vina"  # AutoDock Vina 실행 파일 경로 설정
    try:
        command = [
            vina_executable,
            '--receptor', r_receptor,
            '--flex', f_receptor,
            '--ligand', ligand,
            '--out', output,
            '--log', output.replace('.pdbqt', '.log'),
            '--center_x', '-23.075', '--center_y', '-2.183', '--center_z', '-7.899',  # 이 값을 조정하여 도킹 박스의 중심을 설정하십시오.
            '--size_x', '30', '--size_y', '30', '--size_z', '30'  # 이 값을 조정하여 도킹 박스의 크기를 설정하십시오.
        ]
        result = subprocess.run(command, check=True, stderr=subprocess.PIPE, stdout=subprocess.PIPE)
        print(f"Docked {ligand}, output saved to {output}")
        suc+=1
    except subprocess.CalledProcessError as e:
        print(f"Error docking {ligand}: {e.stderr.decode('utf-8')}")
        fail+=1
        failed.append(ligand)

r_receptor = 'apo_8gfa_rigid.pdbqt'
f_receptor = 'apo_8gfa_flex.pdbqt'
ligands_dir = 'smiles_pdb2/pdbqt'
output_dir = 'f_docked_results'

os.makedirs(output_dir, exist_ok=True)

ligands = [f for f in os.listdir(ligands_dir) if f.endswith('.pdbqt')]

for ligand in ligands:
    ligand_path = os.path.join(ligands_dir, ligand)
    output_path = os.path.join(output_dir, f'docked_{ligand}')
    
    if os.path.exists(output_path): continue

    dock_ligand(r_receptor, f_receptor, ligand_path, output_path)

print(suc, fail, failed)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 43
#      39     output_path = os.path.join(output_dir, f'docked_{ligand}')
#      41     if os.path.exists(output_path): continue
# ---> 43     dock_ligand(r_receptor, f_receptor, ligand_path, output_path)
#      45 print(suc, fail, failed)
#
# Cell In[2], line 21, in dock_ligand(r_receptor, f_receptor, ligand, output)
#      10     command = [
#      11         vina_executable,
#      12         '--receptor', r_receptor,
#    (...)
#      18         '--size_x', '30', '--size_y', '30', '--size_z', '30'  # 이 값을 조정하여 도킹 박스의 크기를 설정하십시오.
#      19     ]
#      20     result = subprocess.run(command, check=True, stderr=subprocess.PIPE, stdout=subprocess.PIPE)
# ---> 21     print(f"Docked {ligand} to {receptor}, output saved to {output}")
#      22     suc+=1
#      23 except subprocess.CalledProcessError as e:
#
# ...

# %%
import os
import pandas as pd

def parse_log_file(log_file):
    """Parse the log file to extract the compound name and affinity value."""
    with open(log_file, 'r') as file:
        lines = file.readlines()
    
    compound_name = os.path.basename(log_file).replace('docked_', '').replace('.log', '')
    affinity = None
    
    for line in lines:
        if line.strip().startswith('1'):
            parts = line.split()
            if len(parts) > 1:
                try:
                    affinity = float(parts[1])
                except ValueError:
                    continue
            break
    
    return compound_name, affinity

def process_log_files(log_dir):
    """Process all log files in the specified directory and return a DataFrame."""
    data = []

    for log_file in os.listdir(log_dir):
        if log_file.endswith('.log'):
            log_path = os.path.join(log_dir, log_file)
            compound_name, affinity = parse_log_file(log_path)
            if affinity is not None:
                data.append((compound_name, affinity))
    
    df = pd.DataFrame(data, columns=['INCI', 'Affinity'])
    return df

# 로그 파일들이 있는 디렉토리 경로를 지정합니다.
log_dir = './f_docked_results/'

# 로그 파일들을 처리하여 데이터프레임 생성
df = process_log_files(log_dir)
df
# Out:
#                                           INCI  Affinity
# 0                               Ethoxydiglycol      -4.5
# 1                             Propylene_Glycol      -3.6
# 2                            Isocetyl_Stearate      -6.3
# 3                    Aminoethylphosphinic_Acid      -4.0
# 4                         Dicaprylyl_Carbonate      -6.6
# ..                                         ...       ...
# 624  Disodium_Ricinoleamido_MEA-Sulfosuccinate      -1.3
# 625                           Triethylhexanoin      -7.9
# 626                              Cetyl_Laurate      -7.6
# 627                             Ethyl_Ferulate      -7.5
# 628                            Hexylresorcinol      -7.0
#
# [629 rows x 2 columns]

# %%
log_dir = './docked_results/'
df_o = process_log_files(log_dir)
df_o
# Out:
#                                           INCI  Affinity
# 0                               Ethoxydiglycol      -4.6
# 1                             Propylene_Glycol      -3.9
# 2                            Isocetyl_Stearate      -6.2
# 3                    Aminoethylphosphinic_Acid      -4.2
# 4                         Dicaprylyl_Carbonate      -6.3
# ..                                         ...       ...
# 622  Disodium_Ricinoleamido_MEA-Sulfosuccinate      -1.3
# 623                           Triethylhexanoin      -7.1
# 624                              Cetyl_Laurate      -6.5
# 625                             Ethyl_Ferulate      -7.1
# 626                            Hexylresorcinol      -6.8
#
# [627 rows x 2 columns]

# %%
def parse_dock(ls): return [f"docked_{name}.pdbqt" for name in ls]
    
sc_df = df.nsmallest(10, 'Affinity')['INCI'].tolist()
sc_df_o = df_o.nsmallest(10, 'Affinity')['INCI'].tolist()
sc_df, sc_df_o = parse_dock(sc_df), parse_dock(sc_df_o)

print(sc_df, sc_df_o)
# Out:
# ['docked_Retinyl_Retinoate.pdbqt', 'docked_CI_47000.pdbqt', 'docked_Solvent_Yellow_33.pdbqt', 'docked_Ketoconazole.pdbqt', 'docked_Cellulose_Acetate_Butyrate.pdbqt', 'docked_Perfluoroperhydrophenanthrene.pdbqt', 'docked_Solvent_Red_23.pdbqt', 'docked_Beta-Carotene.pdbqt', 'docked_CI_61565.pdbqt', 'docked_Red_17.pdbqt'] ['docked_Beta-Carotene.pdbqt', 'docked_Cellulose_Acetate_Butyrate.pdbqt', 'docked_Solvent_Yellow_33.pdbqt', 'docked_CI_47000.pdbqt', 'docked_Perfluoroperhydrophenanthrene.pdbqt', 'docked_CI_75130.pdbqt', 'docked_CI_61565.pdbqt', 'docked_Solvent_Red_23.pdbqt', 'docked_Red_17.pdbqt', 'docked_Retinyl_Retinoate.pdbqt']

# %%
import subprocess

def copy_files(file_list, source_dir, target_dir):
    for file_name in file_list:
        src_file = f"{source_dir}/{file_name}"
        command = ['cp', src_file, target_dir]
        subprocess.run(command, check=True)

src_dir1 = "./f_docked_results/"
src_dir2 = "./docked_results/"
target_dir1 = "./top10fdock/"
target_dir2 = "./top10dock/"

copy_files(sc_df, src_dir1, target_dir1)
copy_files(sc_df_o, src_dir2, target_dir2)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
plt.hist(df_o['Affinity'], bins=20, edgecolor='k', alpha=0.7, label='Rigid')
plt.hist(df['Affinity'], bins=20, edgecolor='k', alpha=0.7, label='Flex')
plt.title('Distribution of Affinity Values')
plt.xlabel('Affinity')
plt.ylabel('Counts')
plt.grid(True)
plt.legend()
plt.show()
